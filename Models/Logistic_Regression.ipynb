# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer
import time

# Function to calculate MAP
def calculate_map(targets, predictions):
    print("Calculating Mean Average Precision (MAP)...")
    map_score = average_precision_score(targets, predictions, average="macro")
    print(f"MAP calculation complete: {map_score:.4f}")
    return map_score

# Load data
print("Loading data...")
start_time = time.time()
train_data = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/train_representations_firstlayer.pt')
test_data = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/test_representations_firstlayer.pt')
train_labels = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/train/labels.pt')
test_labels = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/test/labels.pt')
print(f"Data loaded in {time.time() - start_time:.2f} seconds.")

# Check shapes
print("Inspecting data shapes...")
print(f"Train data shape: {train_data.shape}")  # [20550, 496, 768]
print(f"Test data shape: {test_data.shape}")    # [18886, 496, 768]
print(f"Train labels shape: {train_labels.shape}")  # [20550, 527]
print(f"Test labels shape: {test_labels.shape}")    # [18886, 527]

# Apply max pooling along the time dimension (496)
print("Applying max pooling along the time dimension (496)...")
start_time = time.time()

train_data = torch.max(train_data, dim=1).values.numpy()  # Max pooling across dimension 1 (time)
test_data = torch.max(test_data, dim=1).values.numpy()    # Max pooling across dimension 1 (time)
train_labels = train_labels.numpy()  # [20550, 527]
test_labels = test_labels.numpy()    # [18886, 527]
print(f"Max pooled train data shape: {train_data.shape}")  # [20550, 768]
print(f"Max pooled test data shape: {test_data.shape}")    # [18886, 768]
print(f"Max pooling completed in {time.time() - start_time:.2f} seconds.")

# Train a Logistic Regression Model with OneVsRestClassifier
print("Initializing Logistic Regression model with OneVsRestClassifier...")
start_time = time.time()
model = OneVsRestClassifier(
    LogisticRegression(
        max_iter=1000,  # Set a very low maximum number of iterations to avoid convergence
        solver='saga',
        verbose=1,
        tol=1e-2  # Set a higher tolerance to relax the stopping criterion
    )
    , n_jobs=-1
)
print("Training Logistic Regression model (no convergence required)...")
model.fit(train_data, train_labels)
print(f"Model training complete in {time.time() - start_time:.2f} seconds.")

# Predict probabilities on the test set
print("Generating predictions on test data...")
start_time = time.time()
test_predictions = model.predict_proba(test_data)  # [18886, 527]
print(f"Predictions generated in {time.time() - start_time:.2f} seconds.")

# Metrics
print("Calculating evaluation metrics...")
start_time = time.time()
test_map = calculate_map(test_labels, test_predictions)
test_f1 = f1_score(test_labels, (test_predictions > 0.5).astype(float), average="micro")
print(f"F1-Score calculation complete: {test_f1:.4f}")
print(f"Metrics calculated in {time.time() - start_time:.2f} seconds.")

# Print results
print("\n--- Evaluation Results ---")
print(f"Test MAP: {test_map:.4f}")
print(f"Test F1-Score: {test_f1:.4f}")
# Out:
# Loading data...
# /state/partition1/job-54630313/ipykernel_1716894/2272478307.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_data = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/train_representations_firstlayer.pt')
# /state/partition1/job-54630313/ipykernel_1716894/2272478307.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_data = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/test_representations_firstlayer.pt')
# /state/partition1/job-54630313/ipykernel_1716894/2272478307.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_labels = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/train/labels.pt')
# /state/partition1/job-54630313/ipykernel_1716894/2272478307.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_labels = torch.load('/scratch/rd3629/ml-project/AudioSet-classification/Data/test/labels.pt')
# Data loaded in 34.72 seconds.
# Inspecting data shapes...
# Train data shape: torch.Size([20550, 496, 768])
# Test data shape: torch.Size([18886, 496, 768])
# Train labels shape: torch.Size([20550, 527])
# Test labels shape: torch.Size([18886, 527])
# Applying max pooling along the time dimension (496)...
# Max pooled train data shape: (20550, 768)
# Max pooled test data shape: (18886, 768)
# Max pooling completed in 17.71 seconds.
# Initializing Logistic Regression model with OneVsRestClassifier...
# Training Logistic Regression model (no convergence required)...
# Epoch 1, change: 1.00000000
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.28372264
# Epoch 2, change: 0.35820341
# Epoch 3, change: 0.13491730
# Epoch 3, change: 0.17236398
# Epoch 4, change: 0.09306689
# Epoch 4, change: 0.15872677
# Epoch 5, change: 0.05792713
# Epoch 5, change: 0.11637118
# Epoch 6, change: 0.04973323
# Epoch 6, change: 0.09317320
# Epoch 7, change: 0.03957486
# Epoch 7, change: 0.07894008
# Epoch 8, change: 0.03271864
# Epoch 8, change: 0.06504557
# Epoch 9, change: 0.03064318
# Epoch 9, change: 0.05646257
# Epoch 10, change: 0.02879835
# Epoch 10, change: 0.04912121
# Epoch 11, change: 0.02748861
# Epoch 11, change: 0.04292094
# Epoch 12, change: 0.02623635
# Epoch 12, change: 0.03814463
# Epoch 13, change: 0.02505433
# Epoch 13, change: 0.03394004
# Epoch 14, change: 0.02437561
# Epoch 14, change: 0.03069727
# Epoch 15, change: 0.02338583
# Epoch 15, change: 0.02760200
# Epoch 16, change: 0.02240956
# Epoch 16, change: 0.02464346
# Epoch 17, change: 0.02200919
# Epoch 17, change: 0.02277516
# Epoch 18, change: 0.02093715
# Epoch 18, change: 0.02033995
# Epoch 19, change: 0.02073557
# Epoch 19, change: 0.01940029
# Epoch 20, change: 0.01974845
# Epoch 20, change: 0.01832736
# Epoch 21, change: 0.01951213
# Epoch 21, change: 0.01706324
# Epoch 22, change: 0.01944722
# Epoch 22, change: 0.01658238
# Epoch 23, change: 0.01829749
# Epoch 23, change: 0.01603259
# Epoch 24, change: 0.01749928
# Epoch 24, change: 0.01576057
# Epoch 25, change: 0.01733323
# Epoch 25, change: 0.01537290
# Epoch 26, change: 0.01723593
# Epoch 26, change: 0.01474547
# Epoch 27, change: 0.01711609
# Epoch 27, change: 0.01453877
# Epoch 28, change: 0.01703778
# Epoch 28, change: 0.01431418
# Epoch 29, change: 0.01530418
# Epoch 29, change: 0.01412378
# Epoch 30, change: 0.01523494
# Epoch 30, change: 0.01395697
# Epoch 31, change: 0.01511453
# Epoch 31, change: 0.01378437
# Epoch 32, change: 0.01501918
# Epoch 32, change: 0.01362812
# Epoch 33, change: 0.01496672
# Epoch 33, change: 0.01246321
# Epoch 34, change: 0.01485650
# Epoch 34, change: 0.01231782
# Epoch 35, change: 0.01477603
# Epoch 35, change: 0.01220942
# Epoch 36, change: 0.01311874
# Epoch 36, change: 0.01207659
# Epoch 37, change: 0.01306307
# Epoch 37, change: 0.01197801
# Epoch 38, change: 0.01299905
# Epoch 38, change: 0.01186537
# Epoch 39, change: 0.01294863
# Epoch 39, change: 0.01175043
# Epoch 40, change: 0.01289656
# Epoch 40, change: 0.01163073
# Epoch 41, change: 0.01280902
# Epoch 41, change: 0.01152585
# Epoch 42, change: 0.01266961
# Epoch 42, change: 0.01143491
# Epoch 43, change: 0.01242843
# Epoch 43, change: 0.01135210
# Epoch 44, change: 0.01225822
# Epoch 44, change: 0.01065453
# Epoch 45, change: 0.01049978
# Epoch 45, change: 0.01061260
# Epoch 46, change: 0.01034932
# Epoch 46, change: 0.01050731
# Epoch 47, change: 0.01019346
# Epoch 47, change: 0.01009001
# Epoch 48, change: 0.01003666
# Epoch 48, change: 0.01002053
# convergence after 49 epochs took 11 seconds
# convergence after 49 epochs took 11 seconds
# Epoch 1, change: 1.00000000
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.32207730
# Epoch 2, change: 0.31420061
# Epoch 3, change: 0.19541824
# Epoch 3, change: 0.21197507
# Epoch 4, change: 0.14809094
# Epoch 4, change: 0.14007922
# Epoch 5, change: 0.13827617
# Epoch 5, change: 0.10267344
# Epoch 6, change: 0.10245407
# Epoch 6, change: 0.07857947
# Epoch 7, change: 0.08512350
# Epoch 7, change: 0.06333864
# Epoch 8, change: 0.07165252
# Epoch 8, change: 0.04759251
# Epoch 9, change: 0.06180292
# Epoch 9, change: 0.04354907
# Epoch 10, change: 0.05333446
# Epoch 10, change: 0.04088768
# Epoch 11, change: 0.04718240
# Epoch 11, change: 0.03868486
# Epoch 12, change: 0.04183727
# Epoch 12, change: 0.03680798
# Epoch 13, change: 0.03709965
# Epoch 13, change: 0.03524164
# Epoch 14, change: 0.03413790
# Epoch 14, change: 0.03385748
# Epoch 15, change: 0.03167409
# Epoch 15, change: 0.03319081
# Epoch 16, change: 0.02951325
# Epoch 16, change: 0.03137402
# Epoch 17, change: 0.02730210
# Epoch 17, change: 0.03098603
# Epoch 18, change: 0.02541217
# Epoch 18, change: 0.02926577
# Epoch 19, change: 0.02390737
# Epoch 19, change: 0.02906718
# Epoch 20, change: 0.02302892
# Epoch 20, change: 0.02806816
# Epoch 21, change: 0.02069007
# Epoch 21, change: 0.02733954
# Epoch 22, change: 0.02034128
# Epoch 22, change: 0.02720366
# Epoch 23, change: 0.01850129
# Epoch 23, change: 0.02571031
# Epoch 24, change: 0.01772880
# Epoch 24, change: 0.02567158
# Epoch 25, change: 0.01754019
# Epoch 25, change: 0.02562150
# Epoch 26, change: 0.02415438
# Epoch 26, change: 0.01554780
# Epoch 27, change: 0.01534910
# Epoch 27, change: 0.02415606
# Epoch 28, change: 0.01506342
# Epoch 28, change: 0.02414439
# Epoch 29, change: 0.01478764
# Epoch 29, change: 0.02212418
# Epoch 30, change: 0.02147287
# Epoch 30, change: 0.01458823
# Epoch 31, change: 0.02107485
# Epoch 31, change: 0.01416783
# Epoch 32, change: 0.01337004
# Epoch 32, change: 0.01986746
# Epoch 33, change: 0.01323641
# Epoch 33, change: 0.01866759
# Epoch 34, change: 0.01307580
# Epoch 34, change: 0.01825782
# Epoch 35, change: 0.01294532
# Epoch 35, change: 0.01786058
# Epoch 36, change: 0.01625593
# Epoch 36, change: 0.01283911
# Epoch 37, change: 0.01266185
# Epoch 37, change: 0.01593284
# Epoch 38, change: 0.01177577
# Epoch 38, change: 0.01533903
# Epoch 39, change: 0.01409692
# Epoch 39, change: 0.01165135
# Epoch 40, change: 0.01382216
# Epoch 40, change: 0.01153829
# Epoch 41, change: 0.01146000
# Epoch 41, change: 0.01355844
# Epoch 42, change: 0.01136802
# Epoch 42, change: 0.01331402
# Epoch 43, change: 0.01309588
# Epoch 43, change: 0.01126033
# Epoch 44, change: 0.01118356
# Epoch 44, change: 0.01287666
# Epoch 45, change: 0.01263019
# Epoch 45, change: 0.01108729
# Epoch 46, change: 0.01101247
# Epoch 46, change: 0.01244417
# Epoch 47, change: 0.01094055
# Epoch 47, change: 0.01213730
# Epoch 48, change: 0.01087570
# convergence after 48 epochs took 11 seconds
# Epoch 49, change: 0.01074732
# Epoch 1, change: 1.00000000
# Epoch 50, change: 0.01058493
# Epoch 2, change: 0.34842709
# convergence after 51 epochs took 11 seconds
# Epoch 3, change: 0.24042067
# Epoch 4, change: 0.16738304
# Epoch 1, change: 1.00000000
# Epoch 5, change: 0.13070987
# Epoch 2, change: 0.42282927
# Epoch 6, change: 0.11222525
# Epoch 3, change: 0.22844246
# Epoch 7, change: 0.10058179
# Epoch 4, change: 0.19631536
# Epoch 5, change: 0.15702580
# Epoch 8, change: 0.08720892
# Epoch 6, change: 0.12276953
# Epoch 9, change: 0.07409462
# Epoch 7, change: 0.10083497
# Epoch 10, change: 0.06734627
# Epoch 11, change: 0.06151256
# Epoch 8, change: 0.08548094
# Epoch 12, change: 0.05783695
# Epoch 9, change: 0.07216059
# Epoch 10, change: 0.06388551
# Epoch 13, change: 0.05395404
# Epoch 14, change: 0.05179366
# Epoch 11, change: 0.05771611
# Epoch 15, change: 0.04841561
# Epoch 12, change: 0.05222120
# Epoch 16, change: 0.04655831
# Epoch 13, change: 0.04817044
# Epoch 17, change: 0.04334025
# Epoch 14, change: 0.04466346
# Epoch 18, change: 0.04121790
# Epoch 15, change: 0.04151274
# Epoch 19, change: 0.03859946
# Epoch 16, change: 0.03850958
# Epoch 17, change: 0.03675354
# Epoch 20, change: 0.03662626
# Epoch 18, change: 0.03405503
# Epoch 21, change: 0.03512364
# Epoch 22, change: 0.03261269
# Epoch 19, change: 0.03272668
# Epoch 23, change: 0.03143780
# Epoch 20, change: 0.02980112
# Epoch 21, change: 0.02845500
# Epoch 24, change: 0.03030474
# Epoch 22, change: 0.02746814
# Epoch 25, change: 0.02939373
# Epoch 26, change: 0.02842613
# Epoch 23, change: 0.02657196
# Epoch 24, change: 0.02485477
# Epoch 27, change: 0.02551110
# Epoch 25, change: 0.02311456
# Epoch 28, change: 0.02473530
# Epoch 29, change: 0.02401824
# Epoch 26, change: 0.02263184
# Epoch 27, change: 0.02206763
# Epoch 30, change: 0.02336145
# Epoch 31, change: 0.02275282
# Epoch 28, change: 0.02145619
# Epoch 29, change: 0.02039796
# Epoch 32, change: 0.02211371
# Epoch 33, change: 0.02154511
# Epoch 30, change: 0.01862067
# Epoch 34, change: 0.02091389
# Epoch 31, change: 0.01817227
# Epoch 32, change: 0.01779884
# Epoch 35, change: 0.01877363
# Epoch 33, change: 0.01739806
# Epoch 36, change: 0.01837281
# Epoch 37, change: 0.01796842
# Epoch 34, change: 0.01686595
# Epoch 38, change: 0.01754950
# Epoch 35, change: 0.01675171
# Epoch 39, change: 0.01718521
# Epoch 36, change: 0.01595665
# Epoch 37, change: 0.01441083
# Epoch 40, change: 0.01682113
# Epoch 38, change: 0.01408743
# Epoch 41, change: 0.01643143
# Epoch 42, change: 0.01609491
# Epoch 39, change: 0.01380862
# Epoch 40, change: 0.01367859
# Epoch 43, change: 0.01577460
# Epoch 44, change: 0.01430718
# Epoch 41, change: 0.01339997
# Epoch 42, change: 0.01313830
# Epoch 45, change: 0.01375171
# Epoch 43, change: 0.01288487
# Epoch 46, change: 0.01354145
# Epoch 47, change: 0.01324384
# Epoch 44, change: 0.01264571
# Epoch 45, change: 0.01201885
# Epoch 48, change: 0.01303885
# Epoch 46, change: 0.01119977
# Epoch 49, change: 0.01281243
# Epoch 50, change: 0.01256465
# Epoch 47, change: 0.01107197
# Epoch 51, change: 0.01236454
# Epoch 48, change: 0.01087295
# Epoch 52, change: 0.01214773
# Epoch 49, change: 0.01073675
# Epoch 50, change: 0.01055181
# Epoch 53, change: 0.01196608
# Epoch 51, change: 0.01037654
# Epoch 54, change: 0.01175322
# Epoch 55, change: 0.01156128
# Epoch 52, change: 0.01025546
# Epoch 56, change: 0.01112923
# Epoch 53, change: 0.01007845
# convergence after 57 epochs took 12 seconds
# convergence after 54 epochs took 12 seconds
# Epoch 1, change: 1.00000000
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.32164866
# Epoch 2, change: 0.35012904
# Epoch 3, change: 0.28188053
# Epoch 3, change: 0.21239597
# Epoch 4, change: 0.17795986
# Epoch 4, change: 0.17053086
# Epoch 5, change: 0.14315720
# Epoch 5, change: 0.13079768
# Epoch 6, change: 0.11770082
# Epoch 6, change: 0.10651886
# Epoch 7, change: 0.10093841
# Epoch 7, change: 0.09043898
# Epoch 8, change: 0.08746573
# Epoch 8, change: 0.07744902
# Epoch 9, change: 0.07572588
# Epoch 9, change: 0.06761914
# Epoch 10, change: 0.05924592
# Epoch 10, change: 0.07039600
# Epoch 11, change: 0.06148365
# Epoch 11, change: 0.05279668
# Epoch 12, change: 0.04674724
# Epoch 12, change: 0.05692352
# Epoch 13, change: 0.04178918
# Epoch 13, change: 0.05302816
# Epoch 14, change: 0.05043217
# Epoch 14, change: 0.03766732
# Epoch 15, change: 0.03410752
# Epoch 15, change: 0.04786771
# Epoch 16, change: 0.03047938
# Epoch 16, change: 0.04468410
# Epoch 17, change: 0.04270748
# Epoch 17, change: 0.02797670
# Epoch 18, change: 0.02557765
# Epoch 18, change: 0.04023211
# Epoch 19, change: 0.03675924
# Epoch 19, change: 0.02320506
# Epoch 20, change: 0.02133923
# Epoch 20, change: 0.03517792
# Epoch 21, change: 0.03279253
# Epoch 21, change: 0.01958875
# Epoch 22, change: 0.01847619
# Epoch 22, change: 0.03118319
# Epoch 23, change: 0.03016396
# Epoch 23, change: 0.01748598
# Epoch 24, change: 0.01710860
# Epoch 24, change: 0.02779979
# Epoch 25, change: 0.01679568
# Epoch 25, change: 0.02685535
# Epoch 26, change: 0.01646554
# Epoch 26, change: 0.02538347
# Epoch 27, change: 0.02402521
# Epoch 27, change: 0.01619526
# Epoch 28, change: 0.02352671
# Epoch 28, change: 0.01595036
# Epoch 29, change: 0.02292715
# Epoch 29, change: 0.01569579
# Epoch 30, change: 0.01545809
# Epoch 30, change: 0.02097317
# Epoch 31, change: 0.02024779
# Epoch 31, change: 0.01411564
# Epoch 32, change: 0.01887706
# Epoch 32, change: 0.01389264
# Epoch 33, change: 0.01377955
# Epoch 33, change: 0.01842639
# Epoch 34, change: 0.01360595
# Epoch 34, change: 0.01815556
# Epoch 35, change: 0.01762316
# Epoch 35, change: 0.01342382
# Epoch 36, change: 0.01729592
# Epoch 36, change: 0.01328105
# Epoch 37, change: 0.01317026
# Epoch 37, change: 0.01694370
# Epoch 38, change: 0.01299342
# Epoch 38, change: 0.01652666
# Epoch 39, change: 0.01620043
# Epoch 39, change: 0.01289764
# Epoch 40, change: 0.01407383
# Epoch 40, change: 0.01275384
# Epoch 41, change: 0.01265936
# Epoch 41, change: 0.01357262
# Epoch 42, change: 0.01338930
# Epoch 42, change: 0.01148021
# Epoch 43, change: 0.01313663
# Epoch 43, change: 0.01139518
# Epoch 44, change: 0.01132702
# Epoch 44, change: 0.01292054
# Epoch 45, change: 0.01120738
# Epoch 45, change: 0.01264874
# Epoch 46, change: 0.01247043
# Epoch 46, change: 0.01111042
# Epoch 47, change: 0.01222780
# Epoch 47, change: 0.01100953
# Epoch 48, change: 0.01202977
# Epoch 48, change: 0.01096520
# Epoch 49, change: 0.01185755
# Epoch 49, change: 0.01091086
# Epoch 50, change: 0.01162882
# Epoch 50, change: 0.01083153
# Epoch 51, change: 0.01147712
# Epoch 51, change: 0.01074860
# Epoch 52, change: 0.01132056
# Epoch 52, change: 0.01068086
# Epoch 53, change: 0.01062678
# Epoch 53, change: 0.01111020
# convergence after 54 epochs took 13 seconds
# Epoch 54, change: 0.01027638
# Epoch 55, change: 0.01016499
# Epoch 1, change: 1.00000000
# Epoch 56, change: 0.01001229
# Epoch 2, change: 0.50076258
# convergence after 57 epochs took 13 seconds
# Epoch 3, change: 0.26926249
# Epoch 1, change: 1.00000000
# Epoch 4, change: 0.16970676
# Epoch 2, change: 0.46638605
# Epoch 5, change: 0.13464537
# Epoch 3, change: 0.24516200
# Epoch 6, change: 0.10009623
# Epoch 7, change: 0.08074451
# Epoch 4, change: 0.16307244
# Epoch 5, change: 0.11587964
# Epoch 8, change: 0.06582595
# Epoch 6, change: 0.09262484
# Epoch 9, change: 0.05527645
# Epoch 7, change: 0.07480934
# Epoch 10, change: 0.04748645
# Epoch 8, change: 0.06337020
# Epoch 11, change: 0.04002916
# Epoch 12, change: 0.03522359
# Epoch 9, change: 0.05385134
# Epoch 10, change: 0.04550008
# Epoch 13, change: 0.03017049
# Epoch 11, change: 0.03985669
# Epoch 14, change: 0.02639828
# Epoch 12, change: 0.03461947
# Epoch 15, change: 0.02321382
# Epoch 13, change: 0.03074138
# Epoch 16, change: 0.02060589
# Epoch 14, change: 0.02706238
# Epoch 17, change: 0.01821211
# Epoch 18, change: 0.01774869
# Epoch 15, change: 0.02444921
# Epoch 16, change: 0.02123421
# Epoch 19, change: 0.01659758
# Epoch 17, change: 0.01960746
# Epoch 20, change: 0.01629134
# Epoch 21, change: 0.01603932
# Epoch 18, change: 0.01824310
# Epoch 19, change: 0.01711536
# Epoch 22, change: 0.01581733
# Epoch 20, change: 0.01595767
# Epoch 23, change: 0.01560228
# Epoch 21, change: 0.01501905
# Epoch 24, change: 0.01460576
# Epoch 22, change: 0.01409781
# Epoch 25, change: 0.01445279
# Epoch 26, change: 0.01428412
# Epoch 23, change: 0.01322118
# Epoch 24, change: 0.01239056
# Epoch 27, change: 0.01410337
# Epoch 25, change: 0.01214152
# Epoch 28, change: 0.01397872
# Epoch 26, change: 0.01103749
# Epoch 29, change: 0.01383418
# Epoch 27, change: 0.01046371
# Epoch 30, change: 0.01296403
# Epoch 31, change: 0.01285073
# Epoch 28, change: 0.01030206
# convergence after 29 epochs took 7 seconds
# Epoch 32, change: 0.01274100
# Epoch 33, change: 0.01265354
# Epoch 1, change: 1.00000000
# Epoch 34, change: 0.01225281
# Epoch 2, change: 0.47177935
# Epoch 35, change: 0.01174827
# Epoch 3, change: 0.25691634
# Epoch 36, change: 0.01167915
# Epoch 4, change: 0.17478938
# Epoch 37, change: 0.01157809
# Epoch 5, change: 0.11657690
# Epoch 6, change: 0.09271923
# Epoch 38, change: 0.01151100
# Epoch 7, change: 0.07316674
# Epoch 39, change: 0.01143891
# Epoch 8, change: 0.05877429
# Epoch 40, change: 0.01133128
# Epoch 9, change: 0.04897108
# Epoch 41, change: 0.01127408
# Epoch 10, change: 0.04172151
# Epoch 42, change: 0.01120363
# Epoch 11, change: 0.03497771
# Epoch 43, change: 0.01113890
# Epoch 12, change: 0.02985065
# Epoch 44, change: 0.01109649
# Epoch 13, change: 0.02757224
# Epoch 45, change: 0.01101832
# Epoch 14, change: 0.02552953
# Epoch 46, change: 0.01094261
# Epoch 15, change: 0.02396715
# Epoch 47, change: 0.01089528
# Epoch 16, change: 0.02209474
# Epoch 48, change: 0.01085623
# Epoch 17, change: 0.02052128
# Epoch 49, change: 0.01076912
# Epoch 18, change: 0.01941980
# Epoch 50, change: 0.01073213
# Epoch 19, change: 0.01828958
# convergence after 51 epochs took 11 seconds
# Epoch 20, change: 0.01737531
# Epoch 1, change: 1.00000000
# Epoch 21, change: 0.01629609
# Epoch 2, change: 0.35655835
# Epoch 22, change: 0.01554628
# Epoch 3, change: 0.17361073
# Epoch 23, change: 0.01498080
# Epoch 4, change: 0.11788636
# Epoch 24, change: 0.01485363
# Epoch 5, change: 0.08681034
# Epoch 25, change: 0.01473309
# Epoch 6, change: 0.07178544
# Epoch 26, change: 0.01457201
# Epoch 7, change: 0.06089305
# Epoch 27, change: 0.01363704
# Epoch 8, change: 0.04889996
# Epoch 28, change: 0.01355132
# Epoch 9, change: 0.04406042
# Epoch 29, change: 0.01342528
# Epoch 10, change: 0.04103661
# Epoch 30, change: 0.01336566
# Epoch 11, change: 0.03739013
# Epoch 31, change: 0.01329257
# Epoch 12, change: 0.03459350
# Epoch 32, change: 0.01318186
# Epoch 13, change: 0.03234944
# Epoch 33, change: 0.01310087
# Epoch 14, change: 0.03034648
# Epoch 34, change: 0.01244204
# Epoch 15, change: 0.02843221
# Epoch 35, change: 0.01215793
# Epoch 16, change: 0.02685327
# Epoch 36, change: 0.01210225
# Epoch 17, change: 0.02543070
# Epoch 37, change: 0.01204997
# Epoch 18, change: 0.02422411
# Epoch 38, change: 0.01197528
# Epoch 19, change: 0.02289824
# Epoch 39, change: 0.01192127
# Epoch 20, change: 0.02194158
# Epoch 40, change: 0.01189706
# Epoch 21, change: 0.02076829
# Epoch 41, change: 0.01186251
# Epoch 22, change: 0.02049851
# Epoch 42, change: 0.01178947
# Epoch 23, change: 0.01947299
# Epoch 43, change: 0.01178429
# Epoch 24, change: 0.01858727
# Epoch 44, change: 0.01174293
# Epoch 25, change: 0.01830088
# Epoch 45, change: 0.01169547
# Epoch 26, change: 0.01796761
# Epoch 46, change: 0.01166562
# Epoch 27, change: 0.01643015
# Epoch 47, change: 0.01161982
# Epoch 28, change: 0.01632335
# Epoch 48, change: 0.01160290
# Epoch 29, change: 0.01627086
# convergence after 49 epochs took 11 seconds
# Epoch 30, change: 0.01628201
# Epoch 31, change: 0.01448063
# Epoch 1, change: 1.00000000
# Epoch 32, change: 0.01439430
# Epoch 2, change: 0.36574176
# Epoch 33, change: 0.01437508
# Epoch 3, change: 0.19953550
# Epoch 34, change: 0.01424971
# Epoch 4, change: 0.13320884
# Epoch 35, change: 0.01416866
# Epoch 5, change: 0.10422238
# Epoch 36, change: 0.01429929
# Epoch 6, change: 0.08762527
# Epoch 37, change: 0.01234085
# Epoch 7, change: 0.07685778
# Epoch 38, change: 0.01213992
# Epoch 8, change: 0.06818496
# Epoch 9, change: 0.06029025
# Epoch 39, change: 0.01195547
# Epoch 10, change: 0.05475332
# Epoch 40, change: 0.01174860
# Epoch 11, change: 0.04938401
# Epoch 41, change: 0.01165311
# Epoch 42, change: 0.01142973
# Epoch 12, change: 0.04545889
# Epoch 13, change: 0.04167882
# Epoch 43, change: 0.01122161
# Epoch 14, change: 0.03874429
# Epoch 44, change: 0.01105617
# Epoch 15, change: 0.03586201
# Epoch 45, change: 0.01089679
# Epoch 16, change: 0.03323625
# convergence after 46 epochs took 10 seconds
# Epoch 17, change: 0.03115313
# Epoch 1, change: 1.00000000
# Epoch 18, change: 0.02926345
# Epoch 2, change: 0.41438460
# Epoch 19, change: 0.02799163
# Epoch 3, change: 0.23033778
# Epoch 20, change: 0.02638616
# Epoch 4, change: 0.14680053
# Epoch 21, change: 0.02593979
# Epoch 5, change: 0.12131364
# Epoch 22, change: 0.02387189
# Epoch 6, change: 0.09186510
# Epoch 23, change: 0.02343080
# Epoch 7, change: 0.07350616
# Epoch 24, change: 0.02170698
# Epoch 8, change: 0.06375907
# Epoch 25, change: 0.02103047
# Epoch 9, change: 0.05413759
# Epoch 26, change: 0.02040631
# Epoch 10, change: 0.04608307
# Epoch 27, change: 0.01863452
# Epoch 11, change: 0.04015913
# Epoch 28, change: 0.01815856
# Epoch 12, change: 0.03473986
# Epoch 29, change: 0.01766858
# Epoch 13, change: 0.03214728
# Epoch 30, change: 0.01607014
# Epoch 14, change: 0.03036004
# Epoch 31, change: 0.01582368
# Epoch 15, change: 0.02883151
# Epoch 32, change: 0.01525684
# Epoch 16, change: 0.02655399
# Epoch 33, change: 0.01396195
# Epoch 17, change: 0.02605217
# Epoch 34, change: 0.01379673
# Epoch 18, change: 0.02424132
# Epoch 35, change: 0.01346518
# Epoch 19, change: 0.02327708
# Epoch 36, change: 0.01220373
# Epoch 20, change: 0.02282448
# Epoch 37, change: 0.01187671
# Epoch 21, change: 0.02068275
# Epoch 38, change: 0.01174794
# Epoch 22, change: 0.02047295
# Epoch 39, change: 0.01152493
# Epoch 23, change: 0.01981640
# Epoch 40, change: 0.01137159
# Epoch 24, change: 0.01827578
# Epoch 25, change: 0.01796668
# Epoch 41, change: 0.01121535
# convergence after 42 epochs took 9 seconds
# Epoch 26, change: 0.01774968
# Epoch 27, change: 0.01593841
# Epoch 1, change: 1.00000000
# Epoch 28, change: 0.01583965
# Epoch 2, change: 0.61490941
# Epoch 29, change: 0.01566646
# Epoch 3, change: 0.29762068
# Epoch 30, change: 0.01479118
# Epoch 4, change: 0.20456871
# Epoch 5, change: 0.13991211
# Epoch 31, change: 0.01384541
# Epoch 6, change: 0.11361802
# Epoch 32, change: 0.01366137
# Epoch 33, change: 0.01355890
# Epoch 7, change: 0.09027339
# Epoch 8, change: 0.07482073
# Epoch 34, change: 0.01320475
# Epoch 9, change: 0.06356908
# Epoch 35, change: 0.01186118
# Epoch 36, change: 0.01175616
# Epoch 10, change: 0.05470219
# Epoch 37, change: 0.01165175
# Epoch 11, change: 0.04784805
# Epoch 38, change: 0.01157714
# Epoch 12, change: 0.04287380
# Epoch 13, change: 0.03840212
# Epoch 39, change: 0.01145120
# Epoch 14, change: 0.03449640
# Epoch 40, change: 0.01053184
# Epoch 15, change: 0.03144592
# Epoch 41, change: 0.01037737
# Epoch 16, change: 0.02815161
# Epoch 42, change: 0.01021682
# Epoch 17, change: 0.02669436
# Epoch 43, change: 0.01011252
# Epoch 18, change: 0.02520155
# convergence after 44 epochs took 10 seconds
# Epoch 19, change: 0.02404737
# Epoch 1, change: 1.00000000
# Epoch 20, change: 0.02307164
# Epoch 2, change: 0.38060299
# Epoch 21, change: 0.02169392
# Epoch 3, change: 0.18835272
# Epoch 22, change: 0.02101040
# Epoch 4, change: 0.12023681
# Epoch 23, change: 0.02003418
# Epoch 5, change: 0.08521571
# Epoch 24, change: 0.01918831
# Epoch 6, change: 0.07247122
# Epoch 25, change: 0.01846051
# Epoch 7, change: 0.05934147
# Epoch 26, change: 0.01745269
# Epoch 8, change: 0.04922197
# Epoch 27, change: 0.01701586
# Epoch 9, change: 0.04390258
# Epoch 28, change: 0.01612756
# Epoch 10, change: 0.03708869
# Epoch 29, change: 0.01485596
# Epoch 11, change: 0.03257084
# Epoch 30, change: 0.01468472
# Epoch 12, change: 0.03071821
# Epoch 31, change: 0.01450663
# Epoch 13, change: 0.02844030
# Epoch 32, change: 0.01405925
# Epoch 14, change: 0.02703371
# Epoch 33, change: 0.01251792
# Epoch 15, change: 0.02525216
# Epoch 34, change: 0.01243207
# Epoch 16, change: 0.02501189
# Epoch 35, change: 0.01217284
# Epoch 17, change: 0.02339165
# Epoch 36, change: 0.01212627
# Epoch 18, change: 0.02196387
# Epoch 37, change: 0.01044667
# Epoch 19, change: 0.02165631
# Epoch 38, change: 0.01028409
# Epoch 20, change: 0.01966960
# Epoch 21, change: 0.01958207
# Epoch 39, change: 0.01029452
# Epoch 40, change: 0.01001861
# Epoch 22, change: 0.01860953
# convergence after 41 epochs took 9 seconds
# Epoch 23, change: 0.01739618
# Epoch 24, change: 0.01683423
# Epoch 1, change: 1.00000000
# Epoch 25, change: 0.01588743
# Epoch 2, change: 0.31263334
# Epoch 26, change: 0.01570293
# Epoch 3, change: 0.17543612
# Epoch 27, change: 0.01549165
# Epoch 4, change: 0.12524804
# Epoch 28, change: 0.01535694
# Epoch 5, change: 0.09800134
# Epoch 6, change: 0.08030007
# Epoch 29, change: 0.01522528
# Epoch 7, change: 0.06696519
# Epoch 30, change: 0.01505515
# Epoch 8, change: 0.05995511
# Epoch 31, change: 0.01438451
# Epoch 9, change: 0.05319314
# Epoch 32, change: 0.01416893
# Epoch 10, change: 0.04728211
# Epoch 33, change: 0.01403762
# Epoch 11, change: 0.04210677
# Epoch 34, change: 0.01397687
# Epoch 12, change: 0.03858927
# Epoch 35, change: 0.01326274
# Epoch 13, change: 0.03681489
# Epoch 36, change: 0.01317604
# Epoch 14, change: 0.03493547
# Epoch 37, change: 0.01314253
# Epoch 15, change: 0.03319614
# Epoch 38, change: 0.01312607
# Epoch 16, change: 0.03115332
# Epoch 39, change: 0.01300012
# Epoch 17, change: 0.02980077
# Epoch 40, change: 0.01292869
# Epoch 18, change: 0.02808916
# Epoch 41, change: 0.01287299
# Epoch 19, change: 0.02681086
# Epoch 42, change: 0.01282093
# Epoch 20, change: 0.02629027
# Epoch 43, change: 0.01276238
# Epoch 21, change: 0.02411469
# Epoch 44, change: 0.01249183
# Epoch 22, change: 0.02369812
# Epoch 45, change: 0.01245842
# Epoch 46, change: 0.01237310
# Epoch 23, change: 0.02332358
# Epoch 47, change: 0.01234156
# Epoch 24, change: 0.02134931
# Epoch 48, change: 0.01227453
# Epoch 25, change: 0.02103604
# Epoch 26, change: 0.02068570
# Epoch 49, change: 0.01129952
# Epoch 27, change: 0.01977684
# Epoch 50, change: 0.01098405
# Epoch 28, change: 0.01866830
# Epoch 51, change: 0.01090206
# Epoch 29, change: 0.01845944
# Epoch 52, change: 0.01081265
# Epoch 53, change: 0.01066663
# Epoch 30, change: 0.01820422
# Epoch 31, change: 0.01800805
# Epoch 54, change: 0.01055627
# Epoch 32, change: 0.01633119
# Epoch 55, change: 0.01050667
# Epoch 56, change: 0.01030796
# Epoch 33, change: 0.01609905
# Epoch 34, change: 0.01600531
# Epoch 57, change: 0.01022757
# Epoch 35, change: 0.01569337
# Epoch 58, change: 0.01018026
# Epoch 59, change: 0.01007945
# Epoch 36, change: 0.01545849
# Epoch 37, change: 0.01514901
# convergence after 60 epochs took 14 seconds
# Epoch 38, change: 0.01347593
# Epoch 1, change: 1.00000000
# Epoch 39, change: 0.01319654
# Epoch 2, change: 0.35437194
# Epoch 40, change: 0.01299445
# Epoch 3, change: 0.20850058
# Epoch 41, change: 0.01279827
# Epoch 4, change: 0.15941398
# Epoch 42, change: 0.01252348
# Epoch 5, change: 0.13255706
# Epoch 43, change: 0.01236479
# Epoch 6, change: 0.11542600
# Epoch 44, change: 0.01215926
# Epoch 7, change: 0.10178375
# Epoch 45, change: 0.01193046
# Epoch 8, change: 0.09031649
# Epoch 46, change: 0.01152956
# Epoch 9, change: 0.08071863
# Epoch 47, change: 0.01032540
# Epoch 10, change: 0.07269266
# Epoch 11, change: 0.06660268
# Epoch 48, change: 0.01014723
# Epoch 49, change: 0.01002560
# Epoch 12, change: 0.05980695
# Epoch 13, change: 0.05318394
# convergence after 50 epochs took 12 seconds
# Epoch 14, change: 0.04771718
# Epoch 1, change: 1.00000000
# Epoch 15, change: 0.04233089
# Epoch 2, change: 0.29417464
# Epoch 16, change: 0.03814953
# Epoch 3, change: 0.18168099
# Epoch 17, change: 0.03439656
# Epoch 4, change: 0.13886245
# Epoch 18, change: 0.03074488
# Epoch 5, change: 0.11427440
# Epoch 19, change: 0.02780573
# Epoch 6, change: 0.09522601
# Epoch 20, change: 0.02541459
# Epoch 7, change: 0.08146090
# Epoch 21, change: 0.02357684
# Epoch 8, change: 0.06938577
# Epoch 22, change: 0.02113803
# Epoch 9, change: 0.06103633
# Epoch 23, change: 0.01964487
# Epoch 10, change: 0.05380086
# Epoch 24, change: 0.01817442
# Epoch 11, change: 0.04764325
# Epoch 25, change: 0.01788486
# Epoch 12, change: 0.04225813
# Epoch 26, change: 0.01619784
# Epoch 13, change: 0.03815885
# Epoch 27, change: 0.01597072
# Epoch 14, change: 0.03408938
# Epoch 28, change: 0.01564719
# Epoch 15, change: 0.03100149
# Epoch 29, change: 0.01460128
# Epoch 16, change: 0.02800783
# Epoch 30, change: 0.01388708
# Epoch 17, change: 0.02560309
# Epoch 31, change: 0.01366604
# Epoch 18, change: 0.02344656
# Epoch 32, change: 0.01350515
# Epoch 19, change: 0.02279825
# Epoch 33, change: 0.01290772
# Epoch 20, change: 0.02227329
# Epoch 34, change: 0.01193113
# Epoch 21, change: 0.02085133
# Epoch 35, change: 0.01182826
# Epoch 22, change: 0.02040735
# Epoch 36, change: 0.01163472
# Epoch 23, change: 0.02004612
# Epoch 37, change: 0.01157172
# Epoch 24, change: 0.01964841
# Epoch 38, change: 0.01129639
# Epoch 25, change: 0.01933490
# Epoch 39, change: 0.01012456
# Epoch 26, change: 0.01851846
# convergence after 40 epochs took 9 seconds
# Epoch 27, change: 0.01784755
# Epoch 1, change: 1.00000000
# Epoch 28, change: 0.01756084
# Epoch 2, change: 0.38953200
# Epoch 29, change: 0.01734400
# Epoch 3, change: 0.24542651
# Epoch 30, change: 0.01712929
# Epoch 4, change: 0.17460202
# Epoch 31, change: 0.01691522
# Epoch 5, change: 0.14313519
# Epoch 32, change: 0.01660610
# Epoch 6, change: 0.11313991
# Epoch 33, change: 0.01615791
# Epoch 7, change: 0.09202787
# Epoch 34, change: 0.01629977
# Epoch 8, change: 0.07746110
# Epoch 35, change: 0.01613348
# Epoch 9, change: 0.06532425
# Epoch 36, change: 0.01434535
# Epoch 10, change: 0.05749368
# Epoch 37, change: 0.01421874
# Epoch 11, change: 0.05200923
# Epoch 38, change: 0.01409028
# Epoch 12, change: 0.04607303
# Epoch 39, change: 0.01396736
# Epoch 13, change: 0.04180636
# Epoch 40, change: 0.01385264
# Epoch 14, change: 0.03758457
# Epoch 41, change: 0.01375841
# Epoch 15, change: 0.03395087
# Epoch 42, change: 0.01365217
# Epoch 16, change: 0.03148910
# Epoch 43, change: 0.01354137
# Epoch 17, change: 0.02894161
# Epoch 44, change: 0.01343874
# Epoch 18, change: 0.02688169
# Epoch 45, change: 0.01337061
# Epoch 19, change: 0.02476992
# Epoch 46, change: 0.01328588
# Epoch 20, change: 0.02274797
# Epoch 47, change: 0.01319793
# Epoch 21, change: 0.02137987
# Epoch 48, change: 0.01311862
# Epoch 22, change: 0.02004104
# Epoch 49, change: 0.01303804
# Epoch 23, change: 0.01904219
# Epoch 50, change: 0.01294928
# Epoch 24, change: 0.01834686
# Epoch 51, change: 0.01289308
# Epoch 25, change: 0.01798140
# Epoch 52, change: 0.01281416
# Epoch 26, change: 0.01710299
# Epoch 53, change: 0.01275835
# Epoch 27, change: 0.01587377
# Epoch 54, change: 0.01111321
# Epoch 28, change: 0.01557981
# Epoch 55, change: 0.01107426
# Epoch 29, change: 0.01528503
# Epoch 56, change: 0.01102378
# Epoch 30, change: 0.01504776
# Epoch 57, change: 0.01097628
# Epoch 31, change: 0.01484982
# Epoch 58, change: 0.01091342
# Epoch 32, change: 0.01317628
# Epoch 59, change: 0.01087882
# Epoch 33, change: 0.01299681
# Epoch 60, change: 0.01077426
# Epoch 34, change: 0.01281341
# Epoch 61, change: 0.01061221
# Epoch 35, change: 0.01266191
# Epoch 62, change: 0.01043822
# Epoch 36, change: 0.01249934
# Epoch 63, change: 0.01029271
# Epoch 37, change: 0.01235440
# Epoch 64, change: 0.01013306
# Epoch 38, change: 0.01101458
# convergence after 65 epochs took 15 seconds
# Epoch 39, change: 0.01073924
# Epoch 1, change: 1.00000000
# Epoch 40, change: 0.01063111
# Epoch 2, change: 0.31693274
# Epoch 41, change: 0.01049806
# Epoch 3, change: 0.20573169
# Epoch 42, change: 0.01038692
# Epoch 4, change: 0.16375439
# Epoch 43, change: 0.01028260
# Epoch 5, change: 0.12746829
# Epoch 44, change: 0.01015916
# Epoch 6, change: 0.10363472
# Epoch 45, change: 0.01004580
# Epoch 7, change: 0.09783669
# convergence after 46 epochs took 10 seconds
# Epoch 8, change: 0.07909898
# Epoch 1, change: 1.00000000
# Epoch 9, change: 0.06890195
# Epoch 2, change: 0.34486133
# Epoch 10, change: 0.05995862
# Epoch 3, change: 0.21580310
# Epoch 11, change: 0.05344500
# Epoch 4, change: 0.15554240
# Epoch 12, change: 0.04720920
# Epoch 5, change: 0.12122728
# Epoch 13, change: 0.04242273
# Epoch 6, change: 0.09767734
# Epoch 14, change: 0.03816064
# Epoch 7, change: 0.08201297
# Epoch 15, change: 0.03422461
# Epoch 8, change: 0.07144567
# Epoch 16, change: 0.03115426
# Epoch 9, change: 0.06287823
# Epoch 17, change: 0.02821155
# Epoch 10, change: 0.05520803
# Epoch 18, change: 0.02560045
# Epoch 11, change: 0.04972441
# Epoch 19, change: 0.02361066
# Epoch 12, change: 0.04498689
# Epoch 20, change: 0.02142017
# Epoch 13, change: 0.04088114
# Epoch 21, change: 0.01969787
# Epoch 14, change: 0.03820996
# Epoch 22, change: 0.01819872
# Epoch 15, change: 0.03494667
# Epoch 23, change: 0.01663162
# Epoch 16, change: 0.03233121
# Epoch 24, change: 0.01559274
# Epoch 17, change: 0.03048694
# Epoch 25, change: 0.01451313
# Epoch 18, change: 0.02822598
# Epoch 19, change: 0.02621487
# Epoch 26, change: 0.01413045
# Epoch 20, change: 0.02512437
# Epoch 27, change: 0.01285585
# Epoch 21, change: 0.02287591
# Epoch 28, change: 0.01265769
# Epoch 22, change: 0.02230107
# Epoch 29, change: 0.01242153
# Epoch 23, change: 0.02027174
# Epoch 30, change: 0.01150817
# Epoch 24, change: 0.01987071
# Epoch 31, change: 0.01107190
# Epoch 25, change: 0.01796728
# Epoch 32, change: 0.01079388
# Epoch 26, change: 0.01764882
# Epoch 33, change: 0.01068394
# Epoch 27, change: 0.01654090
# Epoch 34, change: 0.01058784
# Epoch 28, change: 0.01559749
# Epoch 35, change: 0.01047251
# Epoch 29, change: 0.01531771
# convergence after 36 epochs took 8 seconds
# Epoch 30, change: 0.01402118
# Epoch 1, change: 1.00000000
# Epoch 31, change: 0.01346936
# Epoch 2, change: 0.34826529
# Epoch 32, change: 0.01332533
# Epoch 3, change: 0.22077891
# Epoch 33, change: 0.01256445
# Epoch 4, change: 0.18322892
# Epoch 34, change: 0.01156867
# Epoch 5, change: 0.13018702
# Epoch 35, change: 0.01145293
# Epoch 6, change: 0.10944556
# Epoch 36, change: 0.01125588
# Epoch 7, change: 0.09678496
# Epoch 37, change: 0.01037983
# Epoch 8, change: 0.08275042
# convergence after 38 epochs took 9 seconds
# Epoch 9, change: 0.07237801
# Epoch 1, change: 1.00000000
# Epoch 10, change: 0.06406374
# Epoch 2, change: 0.60522616
# Epoch 11, change: 0.05768359
# Epoch 3, change: 0.29699659
# Epoch 12, change: 0.05158754
# Epoch 4, change: 0.19162345
# Epoch 13, change: 0.04648798
# Epoch 5, change: 0.13977794
# Epoch 14, change: 0.04240696
# Epoch 6, change: 0.12475003
# Epoch 15, change: 0.03865670
# Epoch 7, change: 0.10409483
# Epoch 16, change: 0.03527277
# Epoch 8, change: 0.08758695
# Epoch 17, change: 0.03235617
# Epoch 9, change: 0.07662353
# Epoch 18, change: 0.03021389
# Epoch 10, change: 0.06608856
# Epoch 19, change: 0.02786849
# Epoch 11, change: 0.05870877
# Epoch 20, change: 0.02577738
# Epoch 12, change: 0.05237081
# Epoch 21, change: 0.02354377
# Epoch 13, change: 0.04661510
# Epoch 22, change: 0.02207629
# Epoch 14, change: 0.04191529
# Epoch 23, change: 0.02072592
# Epoch 15, change: 0.03790732
# Epoch 16, change: 0.03445965
# Epoch 24, change: 0.01938059
# Epoch 17, change: 0.03151595
# Epoch 25, change: 0.01786655
# Epoch 18, change: 0.02858684
# Epoch 26, change: 0.01702051
# Epoch 19, change: 0.02626367
# Epoch 27, change: 0.01583467
# Epoch 20, change: 0.02398417
# Epoch 28, change: 0.01504990
# Epoch 21, change: 0.02220133
# Epoch 29, change: 0.01400296
# Epoch 22, change: 0.02069619
# Epoch 30, change: 0.01382951
# Epoch 23, change: 0.01928562
# Epoch 31, change: 0.01239653
# Epoch 24, change: 0.01749459
# Epoch 32, change: 0.01111048
# Epoch 25, change: 0.01657319
# Epoch 33, change: 0.01097964
# Epoch 26, change: 0.01624161
# Epoch 34, change: 0.01069469
# Epoch 27, change: 0.01597359
# Epoch 35, change: 0.01070003
# Epoch 28, change: 0.01544111
# convergence after 36 epochs took 8 seconds
# Epoch 29, change: 0.01465235
# Epoch 1, change: 1.00000000
# Epoch 30, change: 0.01435968
# Epoch 2, change: 0.31685948
# Epoch 31, change: 0.01422981
# Epoch 3, change: 0.26123574
# Epoch 32, change: 0.01400330
# Epoch 4, change: 0.16543895
# Epoch 33, change: 0.01381141
# Epoch 5, change: 0.12705943
# Epoch 34, change: 0.01339158
# Epoch 6, change: 0.11301450
# Epoch 35, change: 0.01219053
# Epoch 7, change: 0.09168417
# Epoch 36, change: 0.01201831
# Epoch 8, change: 0.07872906
# Epoch 37, change: 0.01187289
# Epoch 9, change: 0.06892144
# Epoch 38, change: 0.01174331
# Epoch 10, change: 0.06060397
# Epoch 39, change: 0.01160890
# Epoch 11, change: 0.05329496
# Epoch 40, change: 0.01146396
# Epoch 12, change: 0.04733680
# Epoch 41, change: 0.01135299
# Epoch 13, change: 0.04253447
# Epoch 42, change: 0.01125519
# Epoch 14, change: 0.03868508
# Epoch 43, change: 0.01113749
# Epoch 15, change: 0.03503876
# Epoch 44, change: 0.01009552
# Epoch 16, change: 0.03168563
# convergence after 45 epochs took 10 seconds
# Epoch 17, change: 0.02901258
# Epoch 1, change: 1.00000000
# Epoch 18, change: 0.02650828
# Epoch 2, change: 0.27882040
# Epoch 19, change: 0.02423601
# Epoch 3, change: 0.19060522
# Epoch 20, change: 0.02218847
# Epoch 21, change: 0.02063954
# Epoch 4, change: 0.14545272
# Epoch 22, change: 0.01923363
# Epoch 5, change: 0.11969717
# Epoch 23, change: 0.01743223
# Epoch 6, change: 0.09852318
# Epoch 24, change: 0.01629137
# Epoch 7, change: 0.08363372
# Epoch 25, change: 0.01534024
# Epoch 8, change: 0.07304713
# Epoch 26, change: 0.01376169
# Epoch 9, change: 0.06426883
# Epoch 27, change: 0.01347154
# Epoch 10, change: 0.05710007
# Epoch 28, change: 0.01219546
# Epoch 11, change: 0.05118793
# Epoch 29, change: 0.01198830
# Epoch 12, change: 0.04598117
# Epoch 30, change: 0.01115022
# Epoch 13, change: 0.04145220
# Epoch 31, change: 0.01096098
# Epoch 14, change: 0.03791663
# Epoch 32, change: 0.01080088
# Epoch 15, change: 0.03451782
# Epoch 33, change: 0.01067215
# Epoch 16, change: 0.03153243
# Epoch 34, change: 0.01047608
# Epoch 17, change: 0.02895028
# Epoch 35, change: 0.01040502
# Epoch 18, change: 0.02627181
# convergence after 36 epochs took 8 seconds
# Epoch 19, change: 0.02452714
# Epoch 20, change: 0.02268904
# Epoch 1, change: 1.00000000
# Epoch 21, change: 0.02129706
# Epoch 2, change: 0.19604245
# Epoch 3, change: 0.20875819
# Epoch 22, change: 0.01967518
# Epoch 4, change: 0.11538485
# Epoch 23, change: 0.01789489
# Epoch 5, change: 0.06574435
# Epoch 24, change: 0.01702663
# Epoch 6, change: 0.05945935
# Epoch 25, change: 0.01600291
# Epoch 7, change: 0.05344860
# Epoch 26, change: 0.01476930
# Epoch 8, change: 0.05107830
# Epoch 27, change: 0.01408631
# Epoch 9, change: 0.05016857
# Epoch 28, change: 0.01272574
# Epoch 10, change: 0.04669116
# Epoch 29, change: 0.01240918
# Epoch 11, change: 0.04543002
# Epoch 30, change: 0.01115957
# Epoch 12, change: 0.04382220
# Epoch 31, change: 0.01083492
# Epoch 13, change: 0.04288232
# Epoch 32, change: 0.01017367
# Epoch 14, change: 0.04033430
# convergence after 33 epochs took 8 seconds
# Epoch 15, change: 0.03899599
# Epoch 1, change: 1.00000000
# Epoch 16, change: 0.03837249
# Epoch 2, change: 0.21234623
# Epoch 17, change: 0.03779980
# Epoch 3, change: 0.08341666
# Epoch 18, change: 0.03577105
# Epoch 4, change: 0.06206364
# Epoch 19, change: 0.03550112
# Epoch 5, change: 0.06192626
# Epoch 20, change: 0.03471115
# Epoch 6, change: 0.05872936
# Epoch 21, change: 0.03500987
# Epoch 7, change: 0.05418293
# Epoch 22, change: 0.03211856
# Epoch 8, change: 0.05319478
# Epoch 23, change: 0.03143105
# Epoch 9, change: 0.05092864
# Epoch 24, change: 0.03041022
# Epoch 10, change: 0.04976006
# Epoch 25, change: 0.02951136
# Epoch 11, change: 0.04801792
# Epoch 26, change: 0.02851447
# Epoch 12, change: 0.04752686
# Epoch 27, change: 0.02631622
# Epoch 13, change: 0.04300281
# Epoch 28, change: 0.02583539
# Epoch 14, change: 0.03974554
# Epoch 15, change: 0.03693749
# Epoch 29, change: 0.02486057
# Epoch 16, change: 0.03452878
# Epoch 30, change: 0.02454452
# Epoch 17, change: 0.03263065
# Epoch 31, change: 0.02384900
# Epoch 32, change: 0.02303503
# Epoch 18, change: 0.02996228
# Epoch 33, change: 0.02143269
# Epoch 19, change: 0.02883181
# Epoch 34, change: 0.02099176
# Epoch 20, change: 0.02741650
# Epoch 35, change: 0.02046839
# Epoch 21, change: 0.02623893
# Epoch 36, change: 0.02012056
# Epoch 22, change: 0.02558025
# Epoch 37, change: 0.01969827
# Epoch 23, change: 0.02409029
# Epoch 38, change: 0.01925258
# Epoch 24, change: 0.02341271
# Epoch 39, change: 0.01886192
# Epoch 25, change: 0.02287094
# Epoch 40, change: 0.01737523
# Epoch 26, change: 0.02129067
# Epoch 41, change: 0.01702125
# Epoch 27, change: 0.02048128
# Epoch 42, change: 0.01675818
# Epoch 43, change: 0.01644117
# Epoch 28, change: 0.02006514
# Epoch 44, change: 0.01606269
# Epoch 29, change: 0.01966579
# Epoch 45, change: 0.01571854
# Epoch 30, change: 0.01940913
# Epoch 46, change: 0.01538372
# Epoch 31, change: 0.01912345
# Epoch 47, change: 0.01516743
# Epoch 32, change: 0.01744441
# Epoch 48, change: 0.01481906
# Epoch 33, change: 0.01708818
# Epoch 49, change: 0.01458003
# Epoch 34, change: 0.01681547
# Epoch 50, change: 0.01425309
# Epoch 35, change: 0.01664467
# Epoch 51, change: 0.01404279
# Epoch 36, change: 0.01616419
# Epoch 52, change: 0.01372871
# Epoch 37, change: 0.01593049
# Epoch 53, change: 0.01201295
# Epoch 38, change: 0.01428283
# Epoch 54, change: 0.01185594
# Epoch 39, change: 0.01412401
# Epoch 55, change: 0.01165111
# Epoch 40, change: 0.01390408
# Epoch 56, change: 0.01149921
# Epoch 41, change: 0.01367194
# Epoch 42, change: 0.01338977
# Epoch 57, change: 0.01127124
# Epoch 58, change: 0.01110945
# Epoch 43, change: 0.01322407
# Epoch 44, change: 0.01285361
# Epoch 59, change: 0.01093328
# Epoch 45, change: 0.01145737
# Epoch 60, change: 0.01077090
# Epoch 46, change: 0.01121845
# Epoch 61, change: 0.01060784
# Epoch 47, change: 0.01111677
# Epoch 62, change: 0.01046350
# Epoch 48, change: 0.01104697
# Epoch 63, change: 0.01030366
# Epoch 49, change: 0.01088206
# Epoch 64, change: 0.01015083
# Epoch 50, change: 0.01065948
# convergence after 65 epochs took 15 seconds
# Epoch 51, change: 0.01056503
# Epoch 1, change: 1.00000000
# Epoch 52, change: 0.01028232
# Epoch 2, change: 0.44068763
# convergence after 53 epochs took 12 seconds
# Epoch 3, change: 0.27979347
# Epoch 1, change: 1.00000000
# Epoch 4, change: 0.22048759
# Epoch 5, change: 0.17664330
# Epoch 2, change: 0.43061814
# Epoch 6, change: 0.14976127
# Epoch 3, change: 0.21519297
# Epoch 7, change: 0.13172716
# Epoch 4, change: 0.11459119
# Epoch 8, change: 0.11635732
# Epoch 5, change: 0.09034723
# Epoch 9, change: 0.10524326
# Epoch 6, change: 0.06863984
# Epoch 10, change: 0.08974776
# Epoch 7, change: 0.05710466
# Epoch 11, change: 0.07766861
# Epoch 8, change: 0.05064014
# Epoch 12, change: 0.06727506
# Epoch 9, change: 0.04599838
# Epoch 13, change: 0.05933896
# Epoch 10, change: 0.04190337
# Epoch 11, change: 0.03867661
# Epoch 14, change: 0.05309862
# Epoch 12, change: 0.03582622
# Epoch 15, change: 0.04720404
# Epoch 13, change: 0.03368599
# Epoch 16, change: 0.04211321
# Epoch 14, change: 0.03178187
# Epoch 17, change: 0.03806059
# Epoch 15, change: 0.02982415
# Epoch 18, change: 0.03467593
# Epoch 19, change: 0.03151251
# Epoch 16, change: 0.02965379
# Epoch 20, change: 0.02870588
# Epoch 17, change: 0.02929786
# Epoch 21, change: 0.02617816
# Epoch 18, change: 0.02910963
# Epoch 22, change: 0.02405370
# Epoch 23, change: 0.02162325
# Epoch 19, change: 0.02897122
# Epoch 24, change: 0.02016991
# Epoch 20, change: 0.02911153
# Epoch 25, change: 0.01902728
# Epoch 21, change: 0.02912906
# Epoch 26, change: 0.01685759
# Epoch 22, change: 0.02906273
# Epoch 27, change: 0.01587043
# Epoch 23, change: 0.02903915
# Epoch 28, change: 0.01481812
# Epoch 24, change: 0.02928446
# Epoch 29, change: 0.01409167
# Epoch 25, change: 0.02830229
# Epoch 30, change: 0.01383011
# Epoch 26, change: 0.02790952
# Epoch 31, change: 0.01359112
# Epoch 27, change: 0.02764065
# Epoch 32, change: 0.01331956
# Epoch 28, change: 0.02728096
# Epoch 33, change: 0.01324570
# Epoch 29, change: 0.02700083
# Epoch 34, change: 0.01296986
# Epoch 30, change: 0.02674735
# Epoch 35, change: 0.01228668
# Epoch 31, change: 0.02615691
# Epoch 36, change: 0.01187221
# Epoch 32, change: 0.02550291
# Epoch 37, change: 0.01173171
# Epoch 33, change: 0.02485713
# Epoch 34, change: 0.02431414
# Epoch 38, change: 0.01158644
# Epoch 35, change: 0.02378143
# Epoch 39, change: 0.01145469
# Epoch 36, change: 0.02325688
# Epoch 40, change: 0.01129878
# Epoch 37, change: 0.02281458
# Epoch 41, change: 0.01068926
# Epoch 38, change: 0.02227579
# Epoch 42, change: 0.01058517
# Epoch 39, change: 0.02184117
# Epoch 43, change: 0.01047545
# Epoch 40, change: 0.02139120
# Epoch 44, change: 0.01037756
# Epoch 41, change: 0.02099628
# Epoch 45, change: 0.01027367
# Epoch 42, change: 0.02061290
# Epoch 46, change: 0.01014366
# Epoch 43, change: 0.02024724
# Epoch 47, change: 0.01004024
# Epoch 44, change: 0.01988024
# convergence after 48 epochs took 12 seconds
# Epoch 45, change: 0.01953859
# Epoch 1, change: 1.00000000
# Epoch 46, change: 0.01919111
# Epoch 2, change: 0.34363350
# Epoch 47, change: 0.01884941
# Epoch 3, change: 0.18689765
# Epoch 48, change: 0.01852757
# Epoch 4, change: 0.25541207
# Epoch 49, change: 0.01823079
# Epoch 5, change: 0.18756641
# Epoch 50, change: 0.01773696
# Epoch 51, change: 0.01650256
# Epoch 6, change: 0.16039246
# Epoch 52, change: 0.01612916
# Epoch 7, change: 0.14197123
# Epoch 53, change: 0.01592012
# Epoch 8, change: 0.12678646
# Epoch 54, change: 0.01562319
# Epoch 9, change: 0.11437391
# Epoch 10, change: 0.09721429
# Epoch 55, change: 0.01531950
# Epoch 11, change: 0.08337967
# Epoch 56, change: 0.01503512
# Epoch 12, change: 0.07277071
# Epoch 57, change: 0.01472066
# Epoch 58, change: 0.01442962
# Epoch 13, change: 0.06453183
# Epoch 59, change: 0.01415359
# Epoch 14, change: 0.05696947
# Epoch 60, change: 0.01389474
# Epoch 15, change: 0.05094606
# Epoch 61, change: 0.01364502
# Epoch 16, change: 0.04580403
# Epoch 62, change: 0.01338746
# Epoch 17, change: 0.04117135
# Epoch 18, change: 0.03772124
# Epoch 63, change: 0.01315167
# Epoch 19, change: 0.03427956
# Epoch 64, change: 0.01290963
# Epoch 20, change: 0.03132966
# Epoch 21, change: 0.02821025
# Epoch 65, change: 0.01267939
# Epoch 22, change: 0.02664631
# Epoch 23, change: 0.02431430
# Epoch 66, change: 0.01247136
# Epoch 67, change: 0.01224263
# Epoch 24, change: 0.02205051
# Epoch 25, change: 0.02128964
# Epoch 68, change: 0.01204234
# Epoch 26, change: 0.01931758
# Epoch 27, change: 0.01833399
# Epoch 69, change: 0.01184301
# Epoch 70, change: 0.01165150
# Epoch 28, change: 0.01728387
# Epoch 71, change: 0.01146290
# Epoch 29, change: 0.01610179
# Epoch 30, change: 0.01569759
# Epoch 31, change: 0.01457308
# Epoch 72, change: 0.01126330
# Epoch 73, change: 0.01108549
# Epoch 32, change: 0.01433414
# Epoch 74, change: 0.01093007
# Epoch 33, change: 0.01409876
# Epoch 34, change: 0.01378475
# Epoch 75, change: 0.01074537
# Epoch 35, change: 0.01356287
# Epoch 36, change: 0.01320251
# Epoch 76, change: 0.01058894
# Epoch 77, change: 0.01041894
# ...
# Epoch 51, change: 0.01080664
# Epoch 28, change: 0.01288387
# Epoch 52, change: 0.01065256
# Epoch 29, change: 0.01283502
# Epoch 53, change: 0.01048025
# Epoch 30, change: 0.01189049
# Epoch 54, change: 0.01028480
# Epoch 31, change: 0.01180130
# Epoch 55, change: 0.01017000
# Epoch 32, change: 0.01170879
# Epoch 56, change: 0.01000452
# Epoch 33, change: 0.01160726
# convergence after 57 epochs took 40 seconds
# Epoch 34, change: 0.01152855
# Epoch 1, change: 1.00000000
# Epoch 35, change: 0.01143447
# Epoch 2, change: 0.38857719
# Epoch 36, change: 0.01139195
# Epoch 3, change: 0.20740354
# Epoch 37, change: 0.01128581
# Epoch 4, change: 0.13836449
# Epoch 38, change: 0.01120998
# Epoch 5, change: 0.10804074
# Epoch 39, change: 0.01114108
# Epoch 6, change: 0.08706660
# Epoch 40, change: 0.01107960
# Epoch 7, change: 0.07278676
# Epoch 41, change: 0.01101805
# Epoch 8, change: 0.06203407
# Epoch 42, change: 0.01095833
# Epoch 9, change: 0.05581155
# Epoch 43, change: 0.01091418
# Epoch 10, change: 0.05090139
# Epoch 44, change: 0.01083734
# Epoch 11, change: 0.04696723
# Epoch 45, change: 0.01080461
# Epoch 12, change: 0.04309893
# Epoch 46, change: 0.01074769
# Epoch 13, change: 0.03993997
# Epoch 47, change: 0.01070857
# Epoch 14, change: 0.03706922
# Epoch 48, change: 0.01064765
# Epoch 15, change: 0.03469159
# Epoch 49, change: 0.01058789
# Epoch 16, change: 0.03239975
# Epoch 50, change: 0.01054164
# Epoch 17, change: 0.03027208
# Epoch 51, change: 0.01049839
# Epoch 18, change: 0.02866499
# Epoch 52, change: 0.01043941
# Epoch 19, change: 0.02690017
# convergence after 53 epochs took 36 seconds
# Epoch 20, change: 0.02526665
# Epoch 1, change: 1.00000000
# Epoch 21, change: 0.02398665
# Epoch 2, change: 0.33255792
# Epoch 22, change: 0.02253983
# Epoch 3, change: 0.19418448
# Epoch 23, change: 0.02090194
# Epoch 4, change: 0.11678419
# Epoch 24, change: 0.02029280
# Epoch 5, change: 0.09123572
# Epoch 25, change: 0.01873653
# Epoch 6, change: 0.07251784
# Epoch 26, change: 0.01830428
# Epoch 7, change: 0.05858598
# Epoch 27, change: 0.01686197
# Epoch 8, change: 0.04888210
# Epoch 28, change: 0.01607374
# Epoch 9, change: 0.04100360
# Epoch 29, change: 0.01529474
# Epoch 10, change: 0.03472609
# Epoch 30, change: 0.01446748
# Epoch 11, change: 0.03037157
# Epoch 31, change: 0.01363850
# Epoch 12, change: 0.02734819
# Epoch 32, change: 0.01324382
# Epoch 13, change: 0.02497875
# Epoch 33, change: 0.01215630
# Epoch 14, change: 0.02284333
# Epoch 34, change: 0.01202194
# Epoch 15, change: 0.02131261
# Epoch 35, change: 0.01081968
# Epoch 16, change: 0.02037681
# Epoch 36, change: 0.01054831
# Epoch 17, change: 0.01930850
# convergence after 37 epochs took 25 seconds
# Epoch 18, change: 0.01883617
# Epoch 1, change: 1.00000000
# Epoch 19, change: 0.01827722
# Epoch 2, change: 0.25646269
# Epoch 20, change: 0.01744799
# Epoch 3, change: 0.15428039
# Epoch 21, change: 0.01717153
# Epoch 4, change: 0.11037630
# Epoch 22, change: 0.01639240
# Epoch 5, change: 0.08889077
# Epoch 23, change: 0.01597160
# Epoch 6, change: 0.06917792
# Epoch 24, change: 0.01577848
# Epoch 7, change: 0.05561950
# Epoch 25, change: 0.01546691
# Epoch 8, change: 0.04719958
# Epoch 26, change: 0.01466683
# Epoch 9, change: 0.04030194
# Epoch 27, change: 0.01451928
# Epoch 10, change: 0.03448129
# Epoch 28, change: 0.01437965
# Epoch 11, change: 0.02918876
# Epoch 29, change: 0.01426149
# Epoch 12, change: 0.02576682
# Epoch 30, change: 0.01336688
# Epoch 13, change: 0.02242103
# Epoch 31, change: 0.01323672
# Epoch 14, change: 0.01970595
# Epoch 32, change: 0.01300322
# Epoch 15, change: 0.01768883
# Epoch 33, change: 0.01234373
# Epoch 16, change: 0.01720264
# Epoch 34, change: 0.01220840
# Epoch 17, change: 0.01649028
# Epoch 35, change: 0.01210180
# Epoch 18, change: 0.01638809
# Epoch 36, change: 0.01202115
# Epoch 19, change: 0.01577679
# Epoch 37, change: 0.01193393
# Epoch 20, change: 0.01531286
# Epoch 38, change: 0.01184711
# Epoch 21, change: 0.01508091
# Epoch 39, change: 0.01177209
# Epoch 22, change: 0.01441497
# Epoch 40, change: 0.01167601
# Epoch 23, change: 0.01434138
# Epoch 41, change: 0.01162325
# Epoch 24, change: 0.01415344
# Epoch 42, change: 0.01154797
# Epoch 25, change: 0.01324360
# Epoch 43, change: 0.01146460
# Epoch 26, change: 0.01307035
# Epoch 44, change: 0.01139860
# Epoch 27, change: 0.01292523
# convergence after 45 epochs took 31 seconds
# Epoch 28, change: 0.01235321
# Epoch 1, change: 1.00000000
# Epoch 29, change: 0.01201116
# Epoch 2, change: 0.27536744
# Epoch 30, change: 0.01184820
# Epoch 3, change: 0.16670288
# Epoch 31, change: 0.01180300
# Epoch 4, change: 0.13885473
# Epoch 32, change: 0.01101671
# Epoch 5, change: 0.11303747
# Epoch 33, change: 0.01091634
# Epoch 6, change: 0.08756423
# Epoch 34, change: 0.01082927
# Epoch 7, change: 0.07384399
# Epoch 35, change: 0.01015377
# Epoch 8, change: 0.05998073
# Epoch 36, change: 0.01008427
# Epoch 9, change: 0.05182455
# convergence after 37 epochs took 26 seconds
# Epoch 10, change: 0.04490546
# Epoch 1, change: 1.00000000
# Epoch 11, change: 0.03862112
# Epoch 2, change: 0.28237557
# Epoch 12, change: 0.03379459
# Epoch 3, change: 0.17452577
# Epoch 13, change: 0.03003297
# Epoch 4, change: 0.11168951
# Epoch 14, change: 0.02657059
# Epoch 5, change: 0.08395310
# Epoch 15, change: 0.02337967
# Epoch 6, change: 0.06787500
# Epoch 16, change: 0.02105977
# Epoch 7, change: 0.05269695
# Epoch 17, change: 0.01902663
# Epoch 8, change: 0.04269949
# Epoch 18, change: 0.01760529
# Epoch 9, change: 0.03544139
# Epoch 19, change: 0.01572073
# Epoch 10, change: 0.02977297
# Epoch 20, change: 0.01529248
# Epoch 11, change: 0.02523649
# Epoch 21, change: 0.01385114
# Epoch 12, change: 0.02147247
# Epoch 22, change: 0.01361639
# Epoch 13, change: 0.01831151
# Epoch 23, change: 0.01221875
# Epoch 24, change: 0.01187516
# Epoch 14, change: 0.01561722
# Epoch 25, change: 0.01177846
# Epoch 15, change: 0.01434171
# Epoch 26, change: 0.01023709
# Epoch 16, change: 0.01411761
# Epoch 27, change: 0.01014834
# Epoch 17, change: 0.01390024
# Epoch 28, change: 0.01004614
# Epoch 18, change: 0.01369135
# convergence after 29 epochs took 20 seconds
# Epoch 19, change: 0.01352131
# Epoch 1, change: 1.00000000
# Epoch 20, change: 0.01331149
# Epoch 2, change: 0.37012047
# Epoch 21, change: 0.01280933
# Epoch 3, change: 0.21756119
# Epoch 22, change: 0.01267988
# Epoch 4, change: 0.17358500
# Epoch 23, change: 0.01255234
# Epoch 5, change: 0.13864683
# Epoch 24, change: 0.01243369
# Epoch 6, change: 0.11036129
# Epoch 25, change: 0.01236410
# Epoch 7, change: 0.09274118
# Epoch 26, change: 0.01224626
# Epoch 8, change: 0.07924855
# Epoch 27, change: 0.01215177
# Epoch 9, change: 0.06893405
# Epoch 28, change: 0.01207541
# Epoch 10, change: 0.06112870
# Epoch 29, change: 0.01132827
# Epoch 11, change: 0.05425378
# Epoch 30, change: 0.01125711
# Epoch 12, change: 0.04906150
# Epoch 31, change: 0.01119252
# Epoch 13, change: 0.04442006
# Epoch 32, change: 0.01110619
# Epoch 14, change: 0.04027937
# Epoch 33, change: 0.01104265
# Epoch 15, change: 0.03705449
# Epoch 34, change: 0.01098658
# Epoch 16, change: 0.03394918
# Epoch 35, change: 0.01094692
# Epoch 17, change: 0.03099816
# Epoch 36, change: 0.01075218
# Epoch 18, change: 0.02865026
# Epoch 37, change: 0.01068552
# Epoch 19, change: 0.02685343
# Epoch 38, change: 0.01063986
# Epoch 20, change: 0.02432854
# Epoch 39, change: 0.01059519
# Epoch 21, change: 0.02332894
# Epoch 40, change: 0.01054407
# Epoch 22, change: 0.02126883
# Epoch 41, change: 0.01048772
# Epoch 23, change: 0.02058764
# convergence after 42 epochs took 29 seconds
# Epoch 24, change: 0.01833202
# Epoch 1, change: 1.00000000
# Epoch 25, change: 0.01795301
# Epoch 2, change: 0.25265166
# Epoch 26, change: 0.01629543
# Epoch 3, change: 0.14822716
# Epoch 27, change: 0.01555191
# Epoch 4, change: 0.12065202
# Epoch 28, change: 0.01511321
# Epoch 5, change: 0.10216109
# Epoch 29, change: 0.01373556
# Epoch 6, change: 0.09598291
# Epoch 30, change: 0.01319171
# Epoch 7, change: 0.08261351
# Epoch 31, change: 0.01277016
# Epoch 8, change: 0.07585949
# Epoch 32, change: 0.01153501
# Epoch 9, change: 0.06819008
# Epoch 33, change: 0.01135119
# Epoch 10, change: 0.06003613
# Epoch 34, change: 0.01115716
# Epoch 11, change: 0.05416865
# Epoch 35, change: 0.01097064
# Epoch 12, change: 0.04878081
# Epoch 36, change: 0.01082545
# Epoch 13, change: 0.04455565
# Epoch 37, change: 0.01069265
# Epoch 14, change: 0.04055149
# Epoch 38, change: 0.01050894
# Epoch 15, change: 0.03765140
# Epoch 39, change: 0.01039972
# Epoch 16, change: 0.03467297
# Epoch 40, change: 0.01027904
# Epoch 17, change: 0.03236305
# convergence after 41 epochs took 28 seconds
# Epoch 18, change: 0.03047715
# Epoch 1, change: 1.00000000
# Epoch 19, change: 0.02767164
# Epoch 2, change: 0.27854180
# Epoch 20, change: 0.02649800
# Epoch 3, change: 0.21413079
# Epoch 21, change: 0.02574722
# Epoch 4, change: 0.13271622
# Epoch 22, change: 0.02283997
# Epoch 5, change: 0.08858307
# Epoch 23, change: 0.02242339
# Epoch 6, change: 0.06923426
# Epoch 24, change: 0.02179521
# Epoch 7, change: 0.05907821
# Epoch 25, change: 0.01936665
# Epoch 8, change: 0.05216360
# Epoch 26, change: 0.01886970
# Epoch 9, change: 0.04640701
# Epoch 27, change: 0.01841484
# Epoch 10, change: 0.04179258
# Epoch 28, change: 0.01800280
# Epoch 11, change: 0.03804989
# Epoch 29, change: 0.01639097
# Epoch 12, change: 0.03518344
# Epoch 30, change: 0.01586353
# Epoch 13, change: 0.03219652
# Epoch 31, change: 0.01519304
# Epoch 14, change: 0.02999734
# Epoch 32, change: 0.01490111
# Epoch 15, change: 0.02822506
# Epoch 33, change: 0.01458691
# Epoch 16, change: 0.02635644
# Epoch 34, change: 0.01439363
# Epoch 17, change: 0.02478703
# Epoch 35, change: 0.01382395
# Epoch 18, change: 0.02354147
# Epoch 36, change: 0.01359270
# Epoch 19, change: 0.02242607
# Epoch 37, change: 0.01337272
# Epoch 20, change: 0.02174983
# Epoch 38, change: 0.01178366
# Epoch 21, change: 0.02047142
# Epoch 39, change: 0.01159729
# Epoch 22, change: 0.02038273
# Epoch 40, change: 0.01144300
# Epoch 23, change: 0.02000876
# Epoch 41, change: 0.01123555
# Epoch 24, change: 0.01889854
# Epoch 42, change: 0.01077556
# Epoch 25, change: 0.01848093
# Epoch 43, change: 0.01062259
# Epoch 26, change: 0.01804227
# Epoch 44, change: 0.01048038
# Epoch 27, change: 0.01673618
# Epoch 45, change: 0.01031743
# Epoch 28, change: 0.01641292
# Epoch 46, change: 0.01018737
# Epoch 29, change: 0.01611750
# Epoch 47, change: 0.01003333
# Epoch 30, change: 0.01582807
# convergence after 48 epochs took 33 seconds
# Epoch 31, change: 0.01453276
# Epoch 1, change: 1.00000000
# Epoch 32, change: 0.01428200
# Epoch 2, change: 0.30120096
# Epoch 33, change: 0.01407864
# Epoch 3, change: 0.17874439
# Epoch 34, change: 0.01389641
# Epoch 4, change: 0.13635492
# Epoch 35, change: 0.01371006
# Epoch 5, change: 0.12114642
# Epoch 36, change: 0.01349057
# Epoch 6, change: 0.10121202
# Epoch 37, change: 0.01331515
# Epoch 7, change: 0.08934791
# Epoch 38, change: 0.01310242
# Epoch 8, change: 0.08060342
# Epoch 39, change: 0.01102030
# Epoch 9, change: 0.07104452
# Epoch 40, change: 0.01084003
# Epoch 10, change: 0.06304035
# Epoch 41, change: 0.01075098
# Epoch 11, change: 0.05632628
# Epoch 42, change: 0.01059121
# Epoch 12, change: 0.05085168
# Epoch 43, change: 0.01046520
# Epoch 13, change: 0.04634572
# Epoch 44, change: 0.01035175
# Epoch 14, change: 0.04237387
# Epoch 45, change: 0.01020957
# Epoch 15, change: 0.03908570
# Epoch 46, change: 0.01006540
# Epoch 16, change: 0.03600177
# convergence after 47 epochs took 32 seconds
# Epoch 17, change: 0.03388558
# Epoch 1, change: 1.00000000
# Epoch 18, change: 0.03135306
# Epoch 2, change: 0.32632804
# Epoch 19, change: 0.02993623
# Epoch 3, change: 0.19684418
# Epoch 20, change: 0.02738120
# Epoch 4, change: 0.13072251
# Epoch 21, change: 0.02659796
# Epoch 5, change: 0.11220505
# Epoch 22, change: 0.02452130
# Epoch 6, change: 0.08390313
# Epoch 23, change: 0.02328362
# Epoch 7, change: 0.07288621
# Epoch 24, change: 0.02268074
# Epoch 8, change: 0.06238613
# Epoch 25, change: 0.02149409
# Epoch 9, change: 0.05638701
# Epoch 26, change: 0.01978322
# Epoch 10, change: 0.05121190
# Epoch 27, change: 0.01936474
# Epoch 11, change: 0.04653318
# Epoch 28, change: 0.01890597
# Epoch 12, change: 0.04297204
# Epoch 29, change: 0.01818997
# Epoch 13, change: 0.03941947
# Epoch 30, change: 0.01647974
# Epoch 14, change: 0.03640384
# Epoch 31, change: 0.01611459
# Epoch 15, change: 0.03383243
# Epoch 32, change: 0.01584667
# Epoch 16, change: 0.03151706
# Epoch 33, change: 0.01546766
# Epoch 17, change: 0.02854883
# Epoch 34, change: 0.01522459
# Epoch 18, change: 0.02773528
# Epoch 35, change: 0.01339969
# Epoch 19, change: 0.02499111
# Epoch 36, change: 0.01317212
# Epoch 20, change: 0.02426738
# Epoch 37, change: 0.01293485
# Epoch 21, change: 0.02208232
# Epoch 38, change: 0.01274092
# Epoch 22, change: 0.02153772
# Epoch 39, change: 0.01253544
# Epoch 23, change: 0.02017991
# Epoch 40, change: 0.01229739
# Epoch 24, change: 0.01977040
# Epoch 25, change: 0.01941686
# Epoch 41, change: 0.01208445
# Epoch 26, change: 0.01874831
# Epoch 42, change: 0.01126815
# Epoch 27, change: 0.01767451
# Epoch 43, change: 0.01036221
# Epoch 44, change: 0.01020165
# Epoch 28, change: 0.01729056
# Epoch 45, change: 0.01005531
# Epoch 29, change: 0.01701606
# Epoch 30, change: 0.01668532
# convergence after 46 epochs took 31 seconds
# Epoch 31, change: 0.01574669
# Epoch 1, change: 1.00000000
# Epoch 32, change: 0.01525759
# Epoch 2, change: 0.28318208
# Epoch 33, change: 0.01549980
# Epoch 3, change: 0.14378580
# Epoch 34, change: 0.01383207
# Epoch 4, change: 0.09404035
# Epoch 35, change: 0.01372824
# Epoch 5, change: 0.07782800
# Epoch 36, change: 0.01352482
# Epoch 6, change: 0.06526373
# Epoch 37, change: 0.01335815
# Epoch 7, change: 0.06218720
# Epoch 38, change: 0.01314107
# Epoch 8, change: 0.05802894
# Epoch 39, change: 0.01302664
# Epoch 9, change: 0.05413254
# Epoch 40, change: 0.01289055
# Epoch 10, change: 0.05092218
# Epoch 41, change: 0.01272504
# Epoch 11, change: 0.04843267
# Epoch 42, change: 0.01260440
# Epoch 12, change: 0.04617328
# Epoch 43, change: 0.01244170
# Epoch 13, change: 0.04341860
# Epoch 44, change: 0.01233387
# Epoch 14, change: 0.04172526
# Epoch 45, change: 0.01217131
# Epoch 15, change: 0.03965826
# Epoch 46, change: 0.01055594
# Epoch 16, change: 0.03776871
# Epoch 47, change: 0.01050452
# Epoch 17, change: 0.03665776
# Epoch 48, change: 0.01027807
# Epoch 18, change: 0.03490781
# Epoch 49, change: 0.01020909
# Epoch 19, change: 0.03339949
# Epoch 50, change: 0.01010454
# Epoch 20, change: 0.03237837
# Epoch 51, change: 0.01001744
# Epoch 21, change: 0.03090749
# convergence after 52 epochs took 35 seconds
# Epoch 22, change: 0.02970391
# Epoch 1, change: 1.00000000
# Epoch 23, change: 0.02864200
# Epoch 2, change: 0.36677396
# Epoch 24, change: 0.02790034
# Epoch 3, change: 0.20649485
# Epoch 25, change: 0.02488091
# Epoch 4, change: 0.11859845
# Epoch 26, change: 0.02413413
# Epoch 5, change: 0.09080724
# Epoch 27, change: 0.02350461
# Epoch 6, change: 0.08612181
# Epoch 28, change: 0.02282045
# Epoch 7, change: 0.06985381
# Epoch 29, change: 0.02050903
# Epoch 8, change: 0.06319989
# Epoch 30, change: 0.01983115
# Epoch 9, change: 0.05657872
# Epoch 31, change: 0.01942262
# Epoch 10, change: 0.05269722
# Epoch 32, change: 0.01892805
# Epoch 11, change: 0.04807695
# Epoch 33, change: 0.01853563
# Epoch 12, change: 0.04468804
# Epoch 34, change: 0.01738465
# Epoch 13, change: 0.04223314
# Epoch 35, change: 0.01601508
# Epoch 14, change: 0.03980232
# Epoch 36, change: 0.01564770
# Epoch 15, change: 0.03780989
# Epoch 37, change: 0.01536537
# Epoch 16, change: 0.03592605
# Epoch 38, change: 0.01509294
# Epoch 17, change: 0.03456908
# Epoch 39, change: 0.01476708
# Epoch 18, change: 0.03318274
# Epoch 40, change: 0.01444539
# Epoch 19, change: 0.03148727
# Epoch 20, change: 0.02913430
# Epoch 41, change: 0.01265944
# Epoch 21, change: 0.02792987
# Epoch 42, change: 0.01246068
# Epoch 22, change: 0.02633464
# Epoch 43, change: 0.01220803
# Epoch 23, change: 0.02542957
# Epoch 44, change: 0.01209177
# Epoch 24, change: 0.02293323
# Epoch 45, change: 0.01179514
# Epoch 25, change: 0.02192348
# Epoch 46, change: 0.01163809
# Epoch 26, change: 0.02138773
# Epoch 47, change: 0.01142351
# Epoch 27, change: 0.02085155
# Epoch 48, change: 0.01129894
# Epoch 28, change: 0.02011308
# Epoch 49, change: 0.01110472
# Epoch 29, change: 0.01794022
# convergence after 50 epochs took 35 seconds
# Epoch 30, change: 0.01749074
# Epoch 1, change: 1.00000000
# Epoch 31, change: 0.01708392
# Epoch 2, change: 0.40477738
# Epoch 32, change: 0.01674983
# Epoch 3, change: 0.22417714
# Epoch 33, change: 0.01639303
# Epoch 4, change: 0.13108765
# Epoch 34, change: 0.01601980
# Epoch 5, change: 0.10896035
# Epoch 35, change: 0.01419701
# Epoch 6, change: 0.08871619

# %%
# Find a correct test point
test_predictions = model.predict_proba(test_data)  # Get probabilities
binary_predictions = (test_predictions > 0.5).astype(float)  # Threshold predictions

print("Searching for a correct test point where predictions match true labels...")
correct_index = None
for i in range(len(test_labels)):
    if np.array_equal(binary_predictions[i], test_labels[i]):  # Check if predictions match true labels
        correct_index = i
        break

if correct_index is not None:
    print(f"Correct test point found at index {correct_index}")
    predicted_labels = binary_predictions[correct_index]
    true_labels = test_labels[correct_index]
    print("\n--- Correct Test Point ---")
    print(f"Index: {correct_index}")
    print(f"Predicted Labels: {predicted_labels}")
    print(f"True Labels: {true_labels}")
else:
    print("No completely correct test point found.")
